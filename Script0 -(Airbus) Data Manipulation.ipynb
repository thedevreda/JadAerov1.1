# %%
import pandas as pd
import os
import json

# %%
pwd = os.getcwd() 
filepath = os.path.join(pwd, 'Data', 'Data - Airbus Airlines.csv')
filepath1 = os.path.join(pwd, 'Data', 'Data - Boeing Airlines.csv')
filepath2 = os.path.join(pwd, 'Data', 'Data - Boeing_parts.csv') 
filepath3 = os.path.join(pwd, 'Data', 'Data - Airbus_parts.csv')
filepathjson = os.path.join(pwd, 'Json', 'Json - Aircraft Systems.json')
dataset_airbus_airlines = pd.read_csv(filepath, encoding='latin1')
dataset_boeing_airlines = pd.read_csv(filepath1, encoding='latin1')
dataset_boeing_parts = pd.read_csv(filepath2)
dataset_airbus_parts = pd.read_csv(filepath3)
dataset_replacement_interval = pd.read_json(filepathjson)

# %%
dataset_boeing_parts.info() # 2   Model Series  3398 non-null   object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1373 entries, 0 to 1372
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Part Number     1373 non-null   object
#  1   Description     1373 non-null   object
#  2   Aircraft Model  1373 non-null   object
# dtypes: object(3)
# memory usage: 32.3+ KB

# %% [markdown]
# boeing data manipulation

# %%
dataset_boeing_parts.sample(2)
# Out:
#      Part Number           Description  Aircraft Model
# 613  116A9110-27   panel assy - lwr lh  boeing 737-700
# 73     3202446-1  valve - check condit  boeing 737-800

# %% [markdown]
# Spliting the numbers in aircraft model

# %%
dataset_boeing_parts['Aircraft Model'] = dataset_boeing_parts['Aircraft Model'].str.split('boeing ',n=0,expand=True)[1]
dataset_boeing_parts
# Out:
#        Part Number           Description Aircraft Model
# 0             4551  lamp - 28 volt 250 w        737-800
# 1       172A6123-1  panel assy - trailin        737-700
# 2       256A3310-6   transmission assy -        737-700
# 3      65C27384-26             duct assy        737-700
# 4     286A1082-005      wire bundle assy        737-700
# ...            ...                   ...            ...
# 1368        6273-5             fuse assy        737-300
# 1369   110A0113-19  door assy - #10 lh 5        737-700
# 1370    276A3100-9        reservoir assy        737-800
# 1371  07323P000-01        ballscrew assy        737-700
# 1372  07325P000-01   ballscrew assy - te        737-700
#
# [1373 rows x 3 columns]

# %%
dataset_boeing_parts.sample()
# Out:
#     Part Number Description Aircraft Model
# 964  217A1117-1   duct assy        737-700

# %% [markdown]
# Adding aircraft system to the boeing part number database

# %%
# Load your aircraft systems JSON file
with open(filepathjson, 'r') as file:
    aircraft_systems = json.load(file)

def categorize_part(description):
    description = str(description).lower()
    
    for category, data in aircraft_systems.items():
        if any(common_part.lower() in description for common_part in data.get('common_parts', [])):
            return category
        if any(keyword.lower() in description for keyword in data.get('keywords', [])):
            return category
    return 'other'


def get_risk_level(description):
    category = categorize_part(description)
    return aircraft_systems.get(category, {}).get('risk_level', 'Unknown')

def get_priority(description):
    category = categorize_part(description)
    return aircraft_systems.get(category, {}).get('priority ', 'Unknown')


def get_primary_replacement_interval(description):
    category = categorize_part(description)
    replacement_dict = aircraft_systems.get(category, {}).get('replacement_interval', {})
    return list(replacement_dict.values())[0] if replacement_dict else 'On-condition'

def get_replacement_name_by_interval(description):
    category = categorize_part(description)
    interval = get_primary_replacement_interval(description)
    replacement_dict = aircraft_systems.get(category, {}).get('replacement_interval', {})
    for component, rep_interval in replacement_dict.items():
        if rep_interval == interval:
            return component
    return 'Unknown'

def get_geo_targets(description):
    category = categorize_part(description)
    return aircraft_systems.get(category, {}).get('geo_targets', [])

def get_countries(description):
    category = categorize_part(description)
    return aircraft_systems.get(category, {}).get('countries', [])

# Assuming your dataset is a pandas DataFrame with a 'Description' column
dataset_boeing_parts['Airsystem Category'] = dataset_boeing_parts['Description'].apply(categorize_part)
dataset_boeing_parts['Risk Level'] = dataset_boeing_parts['Description'].apply(get_risk_level)
dataset_boeing_parts['Priority'] = dataset_boeing_parts['Description'].apply(get_priority)
dataset_boeing_parts['Replacement Interval'] = dataset_boeing_parts['Description'].apply(get_primary_replacement_interval)
dataset_boeing_parts['Replacement Name'] = dataset_boeing_parts['Description'].apply(get_replacement_name_by_interval)
dataset_boeing_parts['Geo Location'] = dataset_boeing_parts['Description'].apply(get_geo_targets)    # <-- returns a list
dataset_boeing_parts['Countries'] = dataset_boeing_parts['Description'].apply(get_countries)        # <-- returns a list

# %%
dataset_boeing_parts.sample(10)
# Out:
#       Part Number           Description Aircraft Model  \
# 1320  352A1200-42            strut assy        737-700
# 224    313A2121-8            panel assy        737-700
# 203         5002R     inclinometer roll        737-700
# 723   381800-1005  actuator assy - le s        737-800
# 184      1173T211  switch - overheat zo        737-800
# 121   175A1704-13  panel assy - skin 34        737-700
# 1195  2790475-103  valve assy - pressur        737-700
# 502    273A2310-1   cylinder assy - mlg        737-800
# 313    1A226-0217                 track        737-800
# 805     15801-040   control unit assy -        737-700
#
#                 Airsystem Category Risk Level  Priority  \
# 1320           landing_gear_system       High  Critical
# 224                          other    Unknown   Unknown
# 203                          other    Unknown   Unknown
# 723            landing_gear_system       High  Critical
# 184              electrical_system   Moderate  Critical
# 121                          other    Unknown   Unknown
# 1195              hydraulic_system       High  Critical
# 502               hydraulic_system       High  Critical
# 313          cargo_handling_system   Moderate  Moderate
# 805   environmental_control_system   Moderate  Moderate
#
#                                 Replacement Interval Replacement Name  \
# 1320             Every 300-500 landings or on damage            Tires
# 224                                     On-condition          Unknown
# 203                                     On-condition          Unknown
# 723              Every 300-500 landings or on damage            Tires
# 184   Every 2 years or when capacity drops below 80%        Batteries
# 121                                     On-condition          Unknown
# 1195              Every 2 years or on leak detection            Seals
# 502               Every 2 years or on leak detection            Seals
# 313            On-condition; inspect every 12 months           Motors
# 805                          Every 1000 flight hours          Filters
#
#                                     Geo Location  \
# 1320          [Desert, Coastal, Urban, Mountain]
# 224                                           []
# 203                                           []
# 723           [Desert, Coastal, Urban, Mountain]
# 184   [Urban, Island, Coastal, Desert, Mountain]
# 121                                           []
# 1195       [Coastal, Desert, Tropical, Mountain]
# 502        [Coastal, Desert, Tropical, Mountain]
# 313                 [Continental, Desert, Urban]
# 805           [Tropical, Desert, Coastal, Urban]
#
#                                               Countries
# 1320   [Morocco, United States, Egypt, Canada, Germany]
# 224                                                  []
# 203                                                  []
# 723    [Morocco, United States, Egypt, Canada, Germany]
# 184   [Morocco, United States, India, France, Brazil...
# 121                                                  []
# 1195    [Morocco, India, Brazil, United States, Russia]
# 502     [Morocco, India, Brazil, United States, Russia]
# 313                   [Qatar, China, Germany, USA, UAE]
# 805         [Morocco, France, India, Australia, Brazil]

# %%
dataset_boeing_parts = dataset_boeing_parts.explode(column='Countries')
dataset_boeing_parts = dataset_boeing_parts[dataset_boeing_parts['Airsystem Category'] != 'other']
dataset_boeing_parts.sample(10)
# Out:
#        Part Number           Description Aircraft Model  \
# 110     251A4430-4  switch assy - column        737-700
# 511    149A7558-14  panel - flap track a        737-700
# 1164   183A0103-14         elevator assy        737-700
# 4     286A1082-005      wire bundle assy        737-700
# 924       606515-1         valve - check        737-700
# 1184   214C40-1-77   switch - barometric        737-700
# 564         1024-3       switch - dimmer        737-800
# 272    7583695-101           filter assy        737-800
# 466      9000421-2  sensor - flap skew d        737-700
# 1173    213A3220-1  duct assy - heat exc        737-700
#
#                 Airsystem Category Risk Level  Priority  \
# 110              electrical_system   Moderate  Critical
# 511          flight_control_system   Critical  Critical
# 1164         flight_control_system   Critical  Critical
# 4                electrical_system   Moderate  Critical
# 924               hydraulic_system       High  Critical
# 1184             electrical_system   Moderate  Critical
# 564              electrical_system   Moderate  Critical
# 272               hydraulic_system       High  Critical
# 466                avionics_system   Moderate      High
# 1173  environmental_control_system   Moderate  Moderate
#
#                                 Replacement Interval Replacement Name  \
# 110   Every 2 years or when capacity drops below 80%        Batteries
# 511           Every 5 years or on inspection failure   Control Cables
# 1164          Every 5 years or on inspection failure   Control Cables
# 4     Every 2 years or when capacity drops below 80%        Batteries
# 924               Every 2 years or on leak detection            Seals
# 1184  Every 2 years or when capacity drops below 80%        Batteries
# 564   Every 2 years or when capacity drops below 80%        Batteries
# 272               Every 2 years or on leak detection            Seals
# 466                    On-condition or every 5 years         Displays
# 1173                         Every 1000 flight hours          Filters
#
#                                     Geo Location      Countries
# 110   [Urban, Island, Coastal, Desert, Mountain]          Japan
# 511           [Mountain, Coastal, Urban, Desert]  United States
# 1164          [Mountain, Coastal, Urban, Desert]        Morocco
# 4     [Urban, Island, Coastal, Desert, Mountain]         Brazil
# 924        [Coastal, Desert, Tropical, Mountain]         Brazil
# 1184  [Urban, Island, Coastal, Desert, Mountain]         Brazil
# 564   [Urban, Island, Coastal, Desert, Mountain]          India
# 272        [Coastal, Desert, Tropical, Mountain]        Morocco
# 466           [Urban, Island, Coastal, Mountain]        Germany
# 1173          [Tropical, Desert, Coastal, Urban]          India

# %% [markdown]
# modifie the countries (look to notes/country modified)

# %%
countries = {
        'Brunei Darussalam' : 'Brunei',
       'Congo, the Democratic Republic' : 'Democratic Republic of the Congo',
       'Iran, Islamic Republic of' : 'Iran',
       'Slovakia (Slovak Republic)' : 'Slovakia',
       'State of Libya' : 'Libya',
       'Tanzania, United Republic of' : 'Tanzania',
       'Unidentified' : 'Unknown Country',
       'USA' : 'United States'
}
dataset_boeing_airlines.replace({'Country': countries}, inplace=True)

# %% [markdown]
# Joining boeing part with boeing airlines and replcement intreval

# %%
dataset_boeing_merged1 = dataset_boeing_parts.merge(dataset_boeing_airlines, how='left', left_on='Aircraft Model', right_on='Model Series')
dataset_boeing_merged1.sample(10)
# Out:
#           Part Number           Description Aircraft Model  \
# 489175         2S2072   valve - swing check        737-700
# 1072998  315A2295-653  fan duct cowl and th        737-800
# 478390       548388-1                sensor        737-700
# 593638     30100022-3   extinguisher assy -        737-800
# 1325184    213A3220-4  duct assy - heat exc        737-700
# 1270885    3000-46-27      switch - thermal        737-700
# 794353     213A1212-8             duct assy        737-800
# 120218     251A4430-4  switch assy - column        737-800
# 408855   315A2295-220  fan duct cowl and th        737-700
# 1127221   213A1201-76             duct assy        737-700
#
#                    Airsystem Category Risk Level  Priority  \
# 489175               hydraulic_system       High  Critical
# 1072998  environmental_control_system   Moderate  Moderate
# 478390                avionics_system   Moderate      High
# 593638         fire_protection_system   Critical  Critical
# 1325184  environmental_control_system   Moderate  Moderate
# 1270885             electrical_system   Moderate  Critical
# 794353   environmental_control_system   Moderate  Moderate
# 120218              electrical_system   Moderate  Critical
# 408855   environmental_control_system   Moderate  Moderate
# 1127221  environmental_control_system   Moderate  Moderate
#
#                                    Replacement Interval Replacement Name  \
# 489175               Every 2 years or on leak detection            Seals
# 1072998                         Every 1000 flight hours          Filters
# 478390                    On-condition or every 5 years         Displays
# 593638             Every 5 years or after any discharge    Extinguishers
# 1325184                         Every 1000 flight hours          Filters
# 1270885  Every 2 years or when capacity drops below 80%        Batteries
# 794353                          Every 1000 flight hours          Filters
# 120218   Every 2 years or when capacity drops below 80%        Batteries
# 408855                          Every 1000 flight hours          Filters
# 1127221                         Every 1000 flight hours          Filters
#
#                                        Geo Location      Countries  \
# 489175        [Coastal, Desert, Tropical, Mountain]  United States
# 1072998          [Tropical, Desert, Coastal, Urban]         France
# 478390           [Urban, Island, Coastal, Mountain]        Morocco
# 593638          [Urban, Island, Tropical, Mountain]  United States
# 1325184          [Tropical, Desert, Coastal, Urban]         Brazil
# 1270885  [Urban, Island, Coastal, Desert, Mountain]        Germany
# 794353           [Tropical, Desert, Coastal, Urban]      Australia
# 120218   [Urban, Island, Coastal, Desert, Mountain]         Brazil
# 408855           [Tropical, Desert, Coastal, Urban]         Brazil
# 1127221          [Tropical, Desert, Coastal, Urban]          India
#
#                Country                        Airlines Model Series  \
# 489175         Morocco                 Royal Air Maroc      737-700
# 1072998  United States               American Airlines      737-800
# 478390           Kenya                   Kenya Airways      737-700
# 593638   United States       NAS Aviation Services LLC      737-800
# 1325184  United States  International Lease Finance Co      737-700
# 1270885  United States       NAS Aviation Services LLC      737-700
# 794353   United States               CIT Aerospace LLC      737-800
# 120218   United States               American Airlines      737-800
# 408855   United States       NAS Aviation Services LLC      737-700
# 1127221  United States              Southwest Airlines      737-700
#
#                 Region
# 489175          Africa
# 1072998  North America
# 478390          Africa
# 593638   North America
# 1325184  North America
# 1270885  North America
# 794353   North America
# 120218   North America
# 408855   North America
# 1127221  North America

# %% [markdown]
# rename the columns & export the data

# %%
# Remove columns : Countries Country Model Series Region
dataset_boeing_merged1 = dataset_boeing_merged1[['Part Number', 'Description', 'Aircraft Model', 'Airlines', 'Airsystem Category',
       'Risk Level', 'Priority', 'Replacement Interval', 'Replacement Name',
       'Geo Location']]
resultpath = os.path.join(pwd, 'Output', 'Data - Boeing.csv')
dataset_boeing_merged1.to_csv(resultpath, index=False )

# %%
dataset_boeing_merged1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359268 entries, 0 to 1359267
# Data columns (total 10 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Part Number           1359268 non-null  object
#  1   Description           1359268 non-null  object
#  2   Aircraft Model        1359268 non-null  object
#  3   Airlines              1359268 non-null  object
#  4   Airsystem Category    1359268 non-null  object
#  5   Risk Level            1359268 non-null  object
#  6   Priority              1359268 non-null  object
#  7   Replacement Interval  1359268 non-null  object
#  8   Replacement Name      1359268 non-null  object
#  9   Geo Location          1359268 non-null  object
# dtypes: object(10)
# memory usage: 103.7+ MB

# %% [markdown]
# removing the boeing 747-400

# %%
# dataset_boeing_parts['Aircraft Model'].unique()
# data = dataset_boeing_parts[dataset_boeing_parts['Aircraft Model'] != 'boeing 747-400']
# data.to_csv(os.path.join(pwd, 'Data', 'Data - Boeing_parts.csv'), index=False)

# %% [markdown]
# melting the data

# %%
# ds = dataset.melt(id_vars=['airlines', 'Country', 'Region'],var_name='Model Type', value_name='Count') 
# ds[ds["Count"].isnull()] # Delete Opr Ord nan Del 
# # ds[ds["Model Type"].isnull()] # Replace .1 .2 .

# ds.to_csv(os.path.join(pwd, 'Data', 'Data - Airbus Airlines - Melted.csv'), index=False)
