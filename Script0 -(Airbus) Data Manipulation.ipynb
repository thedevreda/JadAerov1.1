# %%
import pandas as pd
import os
import json

# %%
pwd = os.getcwd() 
filepath = os.path.join(pwd, 'Data', 'Data - Airbus Airlines.csv')
filepath2 = os.path.join(pwd, 'Data', 'Data - Airbus_parts.csv')
filepathjson = os.path.join(pwd, 'Json', 'Json - Aircraft Systems.json')
dataset_airbus_airlines = pd.read_csv(filepath, encoding='latin1')
dataset_airbus_parts = pd.read_csv(filepath2)
dataset_replacement_interval = pd.read_json(filepathjson)

# %%
dataset_airbus_parts.info() # 2   Model Series  3398 non-null   object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2185 entries, 0 to 2184
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Part Number     2185 non-null   object
#  1   Description     2025 non-null   object
#  2   Aircraft Model  2025 non-null   object
# dtypes: object(3)
# memory usage: 51.3+ KB

# %% [markdown]
# boeing data manipulation

# %%
dataset_airbus_parts.sample(2)
# Out:
#          Part Number    Description Aircraft Model
# 246   D5323513600100  angle cabinet    angle, assy
# 1195    A25271392046            NaN            NaN

# %% [markdown]
# Adding aircraft system to the boeing part number database

# %%
# Load your aircraft systems JSON file
with open(filepathjson, 'r') as file:
    aircraft_systems = json.load(file)

def categorize_part(description):
    description = str(description).lower()
    
    for category, data in aircraft_systems.items():
        if any(common_part.lower() in description for common_part in data.get('common_parts', [])):
            return category
        if any(keyword.lower() in description for keyword in data.get('keywords', [])):
            return category
    return 'other'


def get_risk_level(description):
    category = categorize_part(description)
    return aircraft_systems.get(category, {}).get('risk_level', 'Unknown')

def get_priority(description):
    category = categorize_part(description)
    return aircraft_systems.get(category, {}).get('priority ', 'Unknown')


def get_primary_replacement_interval(description):
    category = categorize_part(description)
    replacement_dict = aircraft_systems.get(category, {}).get('replacement_interval', {})
    return list(replacement_dict.values())[0] if replacement_dict else 'On-condition'

def get_replacement_name_by_interval(description):
    category = categorize_part(description)
    interval = get_primary_replacement_interval(description)
    replacement_dict = aircraft_systems.get(category, {}).get('replacement_interval', {})
    for component, rep_interval in replacement_dict.items():
        if rep_interval == interval:
            return component
    return 'Unknown'

def get_geo_targets(description):
    category = categorize_part(description)
    return aircraft_systems.get(category, {}).get('geo_targets', [])

def get_countries(description):
    category = categorize_part(description)
    return aircraft_systems.get(category, {}).get('countries', [])

# Assuming your dataset is a pandas DataFrame with a 'Description' column
dataset_airbus_parts['Airsystem Category'] = dataset_airbus_parts['Description'].apply(categorize_part)
dataset_airbus_parts['Risk Level'] = dataset_airbus_parts['Description'].apply(get_risk_level)
dataset_airbus_parts['Priority'] = dataset_airbus_parts['Description'].apply(get_priority)
dataset_airbus_parts['Replacement Interval'] = dataset_airbus_parts['Description'].apply(get_primary_replacement_interval)
dataset_airbus_parts['Replacement Name'] = dataset_airbus_parts['Description'].apply(get_replacement_name_by_interval)
dataset_airbus_parts['Geo Location'] = dataset_airbus_parts['Description'].apply(get_geo_targets)    # <-- returns a list
dataset_airbus_parts['Countries'] = dataset_airbus_parts['Description'].apply(get_countries)        # <-- returns a list

# %%
dataset_airbus_parts.sample(10)
# Out:
#          Part Number       Description Aircraft Model   Airsystem Category  \
# 289   F5757410501800  fairing assembly  fairing, assy                other
# 101   F5451149020800          seal kit      seal assy     hydraulic_system
# 1932  F2818007100000     pipe assembly  pipe assembly                other
# 638   A0041009100700      rod assembly   rod assembly                other
# 1541  A5724294620200          seal kit      seal assy     hydraulic_system
# 2137  A2527285120000     angle cabinet    angle, assy                other
# 1896  A3251214820000   washer assembly         washer                other
# 1461  A5211048222001     retainer lens       retainer                other
# 393   A5461090150400      actuator kit          strip  landing_gear_system
# 1604  D5744359601100      actuator kit        landing  landing_gear_system
#
#      Risk Level  Priority                 Replacement Interval  \
# 289     Unknown   Unknown                         On-condition
# 101        High  Critical   Every 2 years or on leak detection
# 1932    Unknown   Unknown                         On-condition
# 638     Unknown   Unknown                         On-condition
# 1541       High  Critical   Every 2 years or on leak detection
# 2137    Unknown   Unknown                         On-condition
# 1896    Unknown   Unknown                         On-condition
# 1461    Unknown   Unknown                         On-condition
# 393        High  Critical  Every 300-500 landings or on damage
# 1604       High  Critical  Every 300-500 landings or on damage
#
#      Replacement Name                           Geo Location  \
# 289           Unknown                                     []
# 101             Seals  [Coastal, Desert, Tropical, Mountain]
# 1932          Unknown                                     []
# 638           Unknown                                     []
# 1541            Seals  [Coastal, Desert, Tropical, Mountain]
# 2137          Unknown                                     []
# 1896          Unknown                                     []
# 1461          Unknown                                     []
# 393             Tires     [Desert, Coastal, Urban, Mountain]
# 1604            Tires     [Desert, Coastal, Urban, Mountain]
#
#                                              Countries
# 289                                                 []
# 101    [Morocco, India, Brazil, United States, Russia]
# 1932                                                []
# 638                                                 []
# 1541   [Morocco, India, Brazil, United States, Russia]
# 2137                                                []
# 1896                                                []
# 1461                                                []
# 393   [Morocco, United States, Egypt, Canada, Germany]
# 1604  [Morocco, United States, Egypt, Canada, Germany]

# %%
dataset_airbus_parts = dataset_airbus_parts.explode(column='Countries')
dataset_airbus_parts = dataset_airbus_parts[dataset_airbus_parts['Airsystem Category'] != 'other']
dataset_airbus_parts.sample(10)
# Out:
#          Part Number       Description  Aircraft Model  \
# 1328  A2161010300000     duct assembly   duct assembly
# 1905  A271102G220400      actuator kit           strip
# 476   D5335500100000        filter kit      filter air
# 536   A2527642800000      actuator kit        diffuser
# 58    F0003053800000  hose alt cooling  hose, assembly
# 309   D5755018420295      actuator kit           cleat
# 1510  D5347552921490      actuator kit         section
# 674   D2904003800200        half clamp  clamp assembly
# 1331  A2537132623400          seal kit       seal assy
# 1238  A2781009400000  hose alt cooling  hose, assembly
#
#                 Airsystem Category Risk Level  Priority  \
# 1328  environmental_control_system   Moderate  Moderate
# 1905           landing_gear_system       High  Critical
# 476               hydraulic_system       High  Critical
# 536            landing_gear_system       High  Critical
# 58                hydraulic_system       High  Critical
# 309            landing_gear_system       High  Critical
# 1510           landing_gear_system       High  Critical
# 674              electrical_system   Moderate  Critical
# 1331              hydraulic_system       High  Critical
# 1238              hydraulic_system       High  Critical
#
#                                 Replacement Interval Replacement Name  \
# 1328                         Every 1000 flight hours          Filters
# 1905             Every 300-500 landings or on damage            Tires
# 476               Every 2 years or on leak detection            Seals
# 536              Every 300-500 landings or on damage            Tires
# 58                Every 2 years or on leak detection            Seals
# 309              Every 300-500 landings or on damage            Tires
# 1510             Every 300-500 landings or on damage            Tires
# 674   Every 2 years or when capacity drops below 80%        Batteries
# 1331              Every 2 years or on leak detection            Seals
# 1238              Every 2 years or on leak detection            Seals
#
#                                     Geo Location Countries
# 1328          [Tropical, Desert, Coastal, Urban]    Brazil
# 1905          [Desert, Coastal, Urban, Mountain]     Egypt
# 476        [Coastal, Desert, Tropical, Mountain]   Morocco
# 536           [Desert, Coastal, Urban, Mountain]     Egypt
# 58         [Coastal, Desert, Tropical, Mountain]    Russia
# 309           [Desert, Coastal, Urban, Mountain]   Morocco
# 1510          [Desert, Coastal, Urban, Mountain]     Egypt
# 674   [Urban, Island, Coastal, Desert, Mountain]   Germany
# 1331       [Coastal, Desert, Tropical, Mountain]    Brazil
# 1238       [Coastal, Desert, Tropical, Mountain]   Morocco

# %%
dataset_airbus_airlines
# Out:
#                    Country               Airlines Model Series  \
# 0                   France             Air France         A318
# 1           United Kingdom        British Airways         A318
# 2            United States      Frontier Airlines         A318
# 3                    Chile   Latam Airlines Group         A318
# 4            United States  Nas Aviation Services         A318
# ...                    ...                    ...          ...
# 1650                Mexico                Volaris         A321
# 1651                 Spain                Vueling         A321
# 1652               Hungary               Wizz Air         A321
# 1653  United Arab Emirates     Wizz Air Abu Dhabi         A321
# 1654                 China        Xiamen Airlines         A321
#
#                          Region
# 0                        Europe
# 1                        Europe
# 2                 North America
# 3     Latin America & Caribbean
# 4                 North America
# ...                         ...
# 1650  Latin America & Caribbean
# 1651                     Europe
# 1652                     Europe
# 1653                Middle East
# 1654               Asia-Pacific
#
# [1655 rows x 4 columns]

# %% [markdown]
# modifie the countries (look to notes/country modified)

# %%
countries = {
        'Brunei Darussalam' : 'Brunei',
       'Congo, the Democratic Republic' : 'Democratic Republic of the Congo',
       'Iran, Islamic Republic of' : 'Iran',
       'Slovakia (Slovak Republic)' : 'Slovakia',
       'State of Libya' : 'Libya',
       'Tanzania, United Republic of' : 'Tanzania',
       'Unidentified' : 'Unknown Country',
       'USA' : 'United States'
}
dataset_airbus_airlines.replace({'Country': countries}, inplace=True)

# %% [markdown]
# Joining boeing part with boeing airlines and replcement intreval

# %%
dataset_airbus__merged1 = dataset_airbus_parts.merge(dataset_airbus_airlines, how='left', left_on='Countries', right_on='Country')
dataset_airbus__merged1.sample(10)
# Out:
#            Part Number          Description   Aircraft Model  \
# 104528  D2557177322800         actuator kit            strip
# 13868   A2527125301300         actuator kit             mask
# 43400   D9259003402200         actuator kit           psu ay
# 61475   D521107D520000           half clamp   clamp assembly
# 114589  F5777003520200         actuator kit             shim
# 109788     S1565-64309       bearing sleeve  bearing, sleeve
# 92307   A2577120720300         actuator kit          section
# 22275   F5332118321400         actuator kit            strip
# 100483  99A53003001104         actuator kit         calibrat
# 93943   F5218224220000  pushbutton switches           pusher
#
#          Airsystem Category Risk Level  Priority  \
# 104528  landing_gear_system       High  Critical
# 13868   landing_gear_system       High  Critical
# 43400   landing_gear_system       High  Critical
# 61475     electrical_system   Moderate  Critical
# 114589  landing_gear_system       High  Critical
# 109788        engine_system   Critical  Critical
# 92307   landing_gear_system       High  Critical
# 22275   landing_gear_system       High  Critical
# 100483  landing_gear_system       High  Critical
# 93943     electrical_system   Moderate  Critical
#
#                                   Replacement Interval Replacement Name  \
# 104528             Every 300-500 landings or on damage            Tires
# 13868              Every 300-500 landings or on damage            Tires
# 43400              Every 300-500 landings or on damage            Tires
# 61475   Every 2 years or when capacity drops below 80%        Batteries
# 114589             Every 300-500 landings or on damage            Tires
# 109788    Every 1000 flight hours or on leak detection        Oil Seals
# 92307              Every 300-500 landings or on damage            Tires
# 22275              Every 300-500 landings or on damage            Tires
# 100483             Every 300-500 landings or on damage            Tires
# 93943   Every 2 years or when capacity drops below 80%        Batteries
#
#                                       Geo Location      Countries  \
# 104528          [Desert, Coastal, Urban, Mountain]        Germany
# 13868           [Desert, Coastal, Urban, Mountain]        Germany
# 43400           [Desert, Coastal, Urban, Mountain]  United States
# 61475   [Urban, Island, Coastal, Desert, Mountain]  United States
# 114589          [Desert, Coastal, Urban, Mountain]        Germany
# 109788       [Desert, Coastal, Tropical, Mountain]        Morocco
# 92307           [Desert, Coastal, Urban, Mountain]  United States
# 22275           [Desert, Coastal, Urban, Mountain]        Germany
# 100483          [Desert, Coastal, Urban, Mountain]        Germany
# 93943   [Urban, Island, Coastal, Desert, Mountain]        Germany
#
#               Country                        Airlines Model Series  \
# 104528        Germany                       Lufthansa      A321neo
# 13868         Germany                          Condor         A320
# 43400   United States        Global Crossing Airlines         A321
# 61475   United States                      Us Airways      A319ceo
# 114589        Germany                     Germanwings         A320
# 109788        Morocco                 Royal Air Maroc         A321
# 92307   United States  Macquarie Aircraft Leasing Ltd         A320
# 22275         Germany                         Sundair         A320
# 100483        Germany                  Thomas Cook Ag         A320
# 93943         Germany                        Germania         A321
#
#                Region
# 104528         Europe
# 13868          Europe
# 43400   North America
# 61475   North America
# 114589         Europe
# 109788         Africa
# 92307   North America
# 22275          Europe
# 100483         Europe
# 93943          Europe

# %% [markdown]
# rename the columns & export the data

# %%
dataset_airbus__merged1.columns
# Out:
# Index(['Part Number', 'Description', 'Aircraft Model', 'Airsystem Category',
#        'Risk Level', 'Priority', 'Replacement Interval', 'Replacement Name',
#        'Geo Location', 'Countries', 'Country', 'Airlines', 'Model Series',
#        'Region'],
#       dtype='object')

# %%
# Remove columns : Countries Country Model Series Region
dataset_airbus__merged1 = dataset_airbus__merged1[['Part Number', 'Description', 'Airlines', 'Model Series', 'Airsystem Category',
       'Risk Level', 'Priority', 'Replacement Interval', 'Replacement Name',
       'Geo Location']]
resultpath = os.path.join(pwd, 'Output', 'Data - Airbus.csv')
dataset_airbus__merged1.to_csv(resultpath, index=False )

# %%
dataset_airbus__merged1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128186 entries, 0 to 128185
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Part Number           128186 non-null  object
#  1   Description           128186 non-null  object
#  2   Airlines              128046 non-null  object
#  3   Model Series          128046 non-null  object
#  4   Airsystem Category    128186 non-null  object
#  5   Risk Level            128186 non-null  object
#  6   Priority              128186 non-null  object
#  7   Replacement Interval  128186 non-null  object
#  8   Replacement Name      128186 non-null  object
#  9   Geo Location          128186 non-null  object
# dtypes: object(10)
# memory usage: 9.8+ MB

# %% [markdown]
# melting the data

# %%
# ds = dataset.melt(id_vars=['airlines', 'Country', 'Region'],var_name='Model Type', value_name='Count') 
# ds[ds["Count"].isnull()] # Delete Opr Ord nan Del 
# # ds[ds["Model Type"].isnull()] # Replace .1 .2 .

# ds.to_csv(os.path.join(pwd, 'Data', 'Data - Airbus Airlines - Melted.csv'), index=False)
